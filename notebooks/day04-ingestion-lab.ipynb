# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "id": "72ed32e5",
   "metadata": {},
   "source": [
    "# Day 4 — Ingestion Lab\n",
    "\n",
    "Scratch workspace for loading, cleaning, and querying the synthetic coverage data.\n",
    "The \"real\" pipeline lives in `generate_data.py` and `ingest.py` — this notebook is just for exploring."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "5e973bca",
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import sqlite3\n",
    "\n",
    "plans_df = pd.read_csv('../data/plans.csv')\n",
    "claims_df = pd.read_csv('../data/claims.csv')\n",
    "\n",
    "plans_df.head()"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "1ecca9dd",
   "metadata": {},
   "outputs": [],
   "source": [
    "claims_df.head()"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "d351d04c",
   "metadata": {},
   "source": [
    "## Check for nulls and duplicates"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "78744df5",
   "metadata": {},
   "outputs": [],
   "source": [
    "print('plans nulls:\\n', plans_df.isna().sum())\n",
    "print('\\nclaims nulls:\\n', claims_df.isna().sum())\n",
    "print('\\nduplicate plan rows:', plans_df.duplicated().sum())\n",
    "print('duplicate claim rows:', claims_df.duplicated().sum())"
   ]
  },
  {
   "cell_type": "markdown",
   "id": "2426a608",
   "metadata": {},
   "source": [
    "## Query the cleaned SQLite DB\n",
    "\n",
    "(Run `python ingest.py` first from the project root to build `coverage.db`.)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "e8cd21d2",
   "metadata": {},
   "outputs": [],
   "source": [
    "conn = sqlite3.connect('../coverage.db')\n",
    "pd.read_sql_query('SELECT * FROM plans LIMIT 5', conn)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "16e4b67b",
   "metadata": {},
   "outputs": [],
   "source": [
    "pd.read_sql_query('''\n",
    "    SELECT status, COUNT(*) as claim_count\n",
    "    FROM claims\n",
    "    GROUP BY status\n",
    "''', conn)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "id": "2157fdfe",
   "metadata": {},
   "outputs": [],
   "source": [
    "conn.close()"
   ]
  }
 ],
 "metadata": {},
 "nbformat": 4,
 "nbformat_minor": 5
}
